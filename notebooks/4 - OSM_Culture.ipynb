# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import json
import os
 
import sys 
sys.path.insert(0, "../src")
from BrusselsMap import BrusselsMap
from GeoJsonHandler import GeoJsonHandler
from OSMGeoJsonHandler import OSMGeoJsonHandler

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
r_path = r"../data/osm/overpass-turbo/culture.geojson"
path = os.path.join(os.getcwd(), r_path)

cult = OSMGeoJsonHandler(r_path, feature_type='culture')

# %%
cult.gdf.head()
# Out:
#         ID      TYPE                                               NAME  \
# 0  3019360  relation  Maison communale de Schaerbeek - Gemeentehuis ...
# 1  3287536  relation                                      Grand Hospice
# 2  3299877  relation                                              Bozar
# 3  3372706  relation      Maison Communale d'Evere - Gemeentehuis Evere
# 4  3402615  relation                                        Planetarium
#
#             AMENITY                                           geometry  \
# 0          townhall  POLYGON ((4.37316 50.86738, 4.37384 50.86722, ...
# 1  community_centre  POLYGON ((4.34944 50.85351, 4.35000 50.85346, ...
# 2       arts_centre  POLYGON ((4.35936 50.84338, 4.35945 50.84343, ...
# 3          townhall  POLYGON ((4.40244 50.87270, 4.40275 50.87242, ...
# 4       planetarium  POLYGON ((4.33693 50.89321, 4.33697 50.89319, ...
#
#        AREA        LAT       LON
# 0  0.003388  50.867609  4.373674
# 1  0.006501  50.854064  4.350230
# 2  0.008863  50.843731  4.359804
# 3  0.004230  50.872622  4.403071
# 4  0.001638  50.893347  4.337245

# %% [markdown]
# ## Assign neighborhoods

# %%
#Load geodata
r_path = r"../data/final_data/sector.json"
path = os.path.join(os.getcwd(), r_path)
sectors = GeoJsonHandler(path, "NAME_FRE")

# %%
cult.assign_ngh(sectors)
# Out:
#   0%|                                                                                                                                  | 0/451 [00:00<?, ?it/s]C:\Users\vic_t\Anaconda3\envs\mfe_env\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 451/451 [00:33<00:00, 13.46it/s]

# %%
r_path = r"../data/final_data/osm/culture.csv"
path = os.path.join(os.getcwd(), r_path)

cult.gdf.to_csv(path, sep=',', encoding='utf-8-sig', index=False, chunksize=10000)

# %%
cult.gdf.head()
# Out:
#         ID      TYPE                                               NAME  \
# 0  3019360  relation  Maison communale de Schaerbeek - Gemeentehuis ...
# 1  3287536  relation                                      Grand Hospice
# 2  3299877  relation                                              Bozar
# 3  3372706  relation      Maison Communale d'Evere - Gemeentehuis Evere
# 4  3402615  relation                                        Planetarium
#
#             AMENITY                                           geometry  \
# 0          townhall  POLYGON ((4.37316 50.86738, 4.37384 50.86722, ...
# 1  community_centre  POLYGON ((4.34944 50.85351, 4.35000 50.85346, ...
# 2       arts_centre  POLYGON ((4.35936 50.84338, 4.35945 50.84343, ...
# 3          townhall  POLYGON ((4.40244 50.87270, 4.40275 50.87242, ...
# 4       planetarium  POLYGON ((4.33693 50.89321, 4.33697 50.89319, ...
#
#        AREA        LAT       LON             NAME_FRE
# 0  0.003388  50.867609  4.373674            COLLIGNON
# 1  0.006501  50.854064  4.350230  BEGUINAGE - DIXMUDE
# 2  0.008863  50.843731  4.359804       QUARTIER ROYAL
# 3  0.004230  50.872622  4.403071           CONSCIENCE
# 4  0.001638  50.893347  4.337245               HEYSEL

# %%
cult.gdf
