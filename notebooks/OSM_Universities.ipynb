# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import json
import os
 
import sys 
sys.path.insert(0, "../src")
from BrusselsMap import BrusselsMap
from GeoJsonHandler import GeoJsonHandler
from OSMGeoJsonHandler import OSMGeoJsonHandler

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
r_path = r"../data/osm/overpass-turbo/universities.geojson"
path = os.path.join(os.getcwd(), r_path)

univ = OSMGeoJsonHandler(r_path, feature_type='university')

# %%
#Load geodata
r_path = r"../data/final_data/sector.json"
path = os.path.join(os.getcwd(), r_path)
sectors = GeoJsonHandler(path, "NAME_FRE")

# %%
univ.assign_ngh(sectors)
# Out:
#   0%|                                                                                                                                                                                                    | 0/42 [00:00<?, ?it/s]C:\Users\vic_t\anaconda3\envs\mfe\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 42/42 [00:01<00:00, 21.31it/s]

# %%
r_path = r"../data/final_data/osm/university.csv"
path = os.path.join(os.getcwd(), r_path)

univ.gdf.to_csv(path, sep=',', encoding='utf-8-sig', index=False, chunksize=10000)

# %%
univ.gdf
# Out:
#             ID      TYPE                                               NAME  \
# 0      3226490  relation                                              Forum
# 1     11593334  relation     UCLouvain Saint-Louis - Bruxelles (Marie Haps)
# 2     12495988  relation                                              EPHEC
# 3     13366042  relation      Vrije Universiteit Brussel — Campus Etterbeek
# 4     29435713       way                 Vrije Universiteit Brussel (Jette)
# 5     29451706       way                                 VUB — Campus Jette
# 6     30147960       way             Université libre de Bruxelles (Érasme)
# 7     30334638       way                              UCLouvain Saint-Louis
# 8     30358555       way          Université libre de Bruxelles (La Plaine)
# 9     31364142       way                                                  A
# 10   111569911       way                   UCLouvain Bruxelles Saint-Gilles
# 11   150213175       way  Université Libre de Bruxelles (Campus du Solbo...
# 12   226516920       way                                       Auditoires B
# 13   226516926       way                                         Bâtiment C
# 14   226516940       way                                         Bâtiment J
# 15   226517296       way                                         Bâtiment F
# 16   226517382       way  Bâtiment D — Bibliothèque des sciences de la s...
# 17   226517409       way                  ULB — École de santé publique (A)
# 18   228421555       way                                              EPHEC
# 19   256375327       way                       Haute École Francisco Ferrer
# 20   438285749       way     ULB — Faculté des Sciences de la Motricité (N)
# 21   494684472       way         Institut Supérieur Industriel de Bruxelles
# 22   594430724       way                  Koninklijk Conservatorium Brussel
# 23   594675108       way  Conservatoire royal de Bruxelles - Koninklijk ...
# 24   758754359       way        Haute École Léonard de Vinci (Les Tilleuls)
# 25   758756695       way                                                NaN
# 26   758766457       way                         UCLouvain Bruxelles Woluwe
# 27   845186659       way                                                NaN
# 28   847795742       way                                             IESSID
# 29   951694746       way           Erasmushogeschool Brussel — Campus Kanal
# 50   357409230      node     Faculté universitaire de Théologie protestante
# 61  2009770801      node                 Erg - École de recherche graphique
# 62  4418285604      node                                              IHECS
# 63  4587484789      node          Coordination du département INFORSCIENCES
# 64  4896992385      node                         ULB Faculté d'architecture
# 65  5009464057      node                                         Bâtiment E
# 66  5009464058      node                                         Bâtiment G
# 50  university                           POINT (4.40444 50.83548)  0.001352
# 61  university                           POINT (4.35715 50.82207)  0.001352
# 62  university                           POINT (4.34933 50.84393)  0.001352
# 63  university                           POINT (4.39752 50.82020)  0.001352
# 64  university                           POINT (4.37353 50.82726)  0.001352
# 65  university                           POINT (4.26945 50.81349)  0.001352
# 66  university                           POINT (4.26934 50.81390)  0.001352
# 67  university                           POINT (4.39761 50.81983)  0.001352
# 68  university                           POINT (4.40616 50.83735)  0.001352
# 69  university                           POINT (4.39635 50.82158)  0.001352
# 70  university                           POINT (4.36780 50.85946)  0.001352
# 71  university                           POINT (4.45264 50.84938)  0.001352
#
#           LAT       LON               NAME_FRE
# 0   50.819717  4.399174             UNIVERSITE
# 1   50.838677  4.371861      QUARTIER EUROPEEN
# 2   50.849980  4.448510            KAPELLEVELD
# 3   50.822635  4.395242             UNIVERSITE
# 4   50.887842  4.305802   HEYMBOSCH - AZ-JETTE
# 5   50.886653  4.307092   HEYMBOSCH - AZ-JETTE
# 6   50.813500  4.265455   VOGELENZANG - ERASME
# 7   50.853449  4.361139                MARTYRS
# 8   50.819346  4.398632             UNIVERSITE
# 9   50.818674  4.398723             UNIVERSITE
# 10  50.821192  4.349601      HAUT SAINT-GILLES
# 11  50.813311  4.381825               BOONDAEL
# 12  50.813469  4.267316   VOGELENZANG - ERASME
# 13  50.812990  4.267564   VOGELENZANG - ERASME
# 14  50.813640  4.267926   VOGELENZANG - ERASME
# 15  50.814114  4.268554   VOGELENZANG - ERASME
# 16  50.813262  4.268376   VOGELENZANG - ERASME
# 17  50.814242  4.264118   VOGELENZANG - ERASME
# 18  50.873878  4.375626              COLLIGNON
# 19  50.844220  4.343367             ANNEESSENS
# 20  50.814117  4.263419   VOGELENZANG - ERASME
# 21  50.850571  4.363897  NOTRE-DAME AUX NEIGES
# 22  50.839723  4.357190                 SABLON
# 23  50.839026  4.355799                 SABLON
# 24  50.835086  4.376616                JOURDAN
# 25  50.838572  4.372021      QUARTIER EUROPEEN
# 26  50.850882  4.453689            KAPELLEVELD
# 27  50.838858  4.371583      QUARTIER EUROPEEN
# 28  50.818558  4.367873    BRUGMANN - LEPOUTRE
# 29  50.851767  4.342221               DANSAERT
# 50  50.835480  4.404436           SAINT-MICHEL
# 61  50.822073  4.357153    BRUGMANN - LEPOUTRE
# 62  50.843925  4.349333            GRAND PLACE
# 63  50.820200  4.397517             UNIVERSITE
# 64  50.827259  4.373530      FLAGEY - MALIBRAN
# 65  50.813486  4.269449   VOGELENZANG - ERASME
# 66  50.813896  4.269335   VOGELENZANG - ERASME
# 67  50.819828  4.397609             UNIVERSITE
# 68  50.837347  4.406164           SAINT-MICHEL
# 69  50.821577  4.396347             UNIVERSITE
# 70  50.859459  4.367797       QUARTIER BRABANT
# 71  50.849377  4.452640            KAPELLEVELD
